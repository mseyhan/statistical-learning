# %%
# sadece sayılar ve latin karakterler için, özel karakterler, ö,ü,i,ç vb. içeren metinlerde çalışmaz.
# sonuncuda virgül olduğunda bug
import re
def up(x):
    return(x.upper())
def no_up(x):
    return(x)

def proper_commatizer(slice:bool,quotes:bool,upper:bool):
    stripped = commatizable.strip().splitlines()
    output = ''
    up_func = no_up
    if upper == True:
        up_func = up

    if quotes == True:
        cover = "'"
    else:
        cover = ""
    if slice == False:
        for i in range(len(stripped)):
            if re.match(r'^[a-zA-Z0-9]*$', stripped[i]) and i != len(stripped)-1:
                z = str(cover+stripped[i]+cover)+','
                output = output + up_func(z)
            else:
                z = str(cover+stripped[i]+cover)
                output = output + up_func(z)
                #print(z)
    else:
        for i in range(len(stripped)):
            if re.match(r'^[a-zA-Z0-9 ]*$', stripped[i]) and i != len(stripped)-1:
                z = str(cover+stripped[i]+cover)+','
                print(z)
            else:
                z = str(cover+stripped[i]+cover)
                print(z)
    print(output)

# %%
# insert commatizable components:
commatizable = '''
26c36e7efa
26c36e800f
26c36e8129
26c36e8182
26c36e81e0
26c36e823f
26c36e829d
26c36e82fb
26c36e8356
26c36e83b3
26c36e8418
26c36e847b
26c36e84d2
26c36e853a
26c36e8595
26c36e85fc
26c36e8653
26c36e86b2
26c36e870f
26c36e8772
26c36e87cf
26c36e8830
26c36e8898
26c36e8912
26c36e896d
26c36e89cd
26c36e8a2e
26c36e8a90
26c36e8afc
26c36e8b5e
26c36e8bba
26c36e8c13
26c36e8c74
26c36e8cd1
26c36e8d2e
26c36e8d8e
26c0726e27
26c0726f98
26c072701d
26c0727161
26c07271c8
26c30731a3
26c0726b87
26c308e2a5
26c072708a
26c07270f9
26c0727239
26c072729e
26c308e3b8
26c308e415
26c308e473
26c308e4c8
26c308e529
26c308e58d
26c07277c2
26c072781d
26c308def3
26c308df50
26c308dfab
26c308e010
26c308e06d
26c308e0c7
26c308e128
26c308e185
26c308e1e0
26c308e244
26c308e306
26c308e35b
26c308e5ec
26c308e65e
26c308e6be
26c308e71c
26c308e775
26c308e7df
26c308e837
26c308e88f
26c308e8ef
26c308e949
26c308e9af
26c308ea11
26c308ea76
26c308ead5
26c308eb30
26c308eb92
26c308ebfa
26c308ec57
26c308ecb1
26c308ed09
26c36dcf22
26c3072bc5
26c3072c22
26c3072c84
26c3072cf5
26c3072e61
26c3072f13
26c3072fce
26c3073025
26c3073086
26c30730e7
26c3073149
26c3073334
26c307339f
26c3073402
26c3073464
26c30734c9
26c3073521
26c307357f
26c30735dd
26c3073632
26c30736ed
26c3073754
26c3073816
26c3073888
26c307394d
26ca354a62
26ca354ab1
26ca354b01
26ca354b4f
26ca354b9e
26ca354bea
26ca354c38
26ca354ccf
26c0726f1c
26c07272ff
26c072736c
26c07273e8
26c072744d
26c0727518
26c0727578
26c07275d2
26ca355954
26ca3559a3
26ca3559f0
26ca355a3d
26ca355a88
26ca355ad6
26ca355b22
26ca355b6c
26ca355bbb
26cacbfd34
26cacbfd9a
26cacbfdea
26cacbfe39




'''

# %%
proper_commatizer(slice=False,quotes=True,upper=True)
# Out:
# '26C36E7EFA','26C36E800F','26C36E8129','26C36E8182','26C36E81E0','26C36E823F','26C36E829D','26C36E82FB','26C36E8356','26C36E83B3','26C36E8418','26C36E847B','26C36E84D2','26C36E853A','26C36E8595','26C36E85FC','26C36E8653','26C36E86B2','26C36E870F','26C36E8772','26C36E87CF','26C36E8830','26C36E8898','26C36E8912','26C36E896D','26C36E89CD','26C36E8A2E','26C36E8A90','26C36E8AFC','26C36E8B5E','26C36E8BBA','26C36E8C13','26C36E8C74','26C36E8CD1','26C36E8D2E','26C36E8D8E','26C0726E27','26C0726F98','26C072701D','26C0727161','26C07271C8','26C30731A3','26C0726B87','26C308E2A5','26C072708A','26C07270F9','26C0727239','26C072729E','26C308E3B8','26C308E415','26C308E473','26C308E4C8','26C308E529','26C308E58D','26C07277C2','26C072781D','26C308DEF3','26C308DF50','26C308DFAB','26C308E010','26C308E06D','26C308E0C7','26C308E128','26C308E185','26C308E1E0','26C308E244','26C308E306','26C308E35B','26C308E5EC','26C308E65E','26C308E6BE','26C308E71C','26C308E775','26C308E7DF','26C308E837','26C308E88F','26C308E8E
# ...
